# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
variation = pd.read_csv('../data/clean/client_id_variation.csv')
variation.head(5)
# Out:
#    client_id Variation
# 0    9988021      Test
# 1    8320017      Test
# 2    4033851   Control
# 3    1982004      Test
# 4    9294070   Control

# %%
time_spent = pd.read_csv('../data/clean/time_spent.csv')
time_spent = time_spent.drop(columns = 'Unnamed: 0')
time_spent
# Out:
#         client_id             visitor_id                      visit_id  \
# 0             169  201385055_71273495308  749567106_99161211863_557568
# 1             169  201385055_71273495308  749567106_99161211863_557568
# 2             169  201385055_71273495308  749567106_99161211863_557568
# 3             169  201385055_71273495308  749567106_99161211863_557568
# 4             546  475037402_89828530214    731811517_9330176838_94847
# ...           ...                    ...                           ...
# 413379    9999839  948322592_28990736246  715530422_68620416793_515645
# 413380    9999875   738878760_1556639849    931268933_219402947_599432
# 413381    9999875   738878760_1556639849    931268933_219402947_599432
# 413382    9999875   738878760_1556639849    931268933_219402947_599432
# 413383    9999875   738878760_1556639849    931268933_219402947_599432
#
#        from_step  to_step       time_spent  is_error
# 0          start   step_1  0 days 00:00:09     False
# 1         step_1   step_2  0 days 00:00:46     False
# 2         step_2   step_3  0 days 00:01:34     False
# 3         step_3  confirm  0 days 00:01:04     False
# 4          start   step_1  0 days 00:00:10     False
# ...          ...      ...              ...       ...
# 413379    step_3  confirm  0 days 00:00:35     False
# 413380     start   step_1  0 days 00:00:07     False
# 413381    step_1   step_2  0 days 00:01:39     False
# 413382    step_2   step_3  0 days 00:03:11     False
# 413383    step_3  confirm  0 days 00:03:41     False
#
# [413384 rows x 7 columns]

# %%
df = pd.merge(variation, time_spent, on = 'client_id')
df
# Out:
#         client_id Variation             visitor_id  \
# 0         9988021      Test   580560515_7732621733
# 1         9988021      Test   580560515_7732621733
# 2         9988021      Test   580560515_7732621733
# 3         9988021      Test   580560515_7732621733
# 4         9988021      Test   580560515_7732621733
# ...           ...       ...                    ...
# 172701    6334360      Test  629124187_65258232847
# 172702    6334360      Test  629124187_65258232847
# 172703    6334360      Test  629124187_65258232847
# 172704    6334360      Test  629124187_65258232847
# 172705    6334360      Test  629124187_65258232847
#
#                             visit_id from_step  to_step       time_spent  \
# 0       781255054_21935453173_531117     start   step_1  0 days 00:00:39
# 1       781255054_21935453173_531117    step_1   step_2  0 days 00:00:14
# 2       781255054_21935453173_531117    step_2   step_3  0 days 00:00:49
# 3       781255054_21935453173_531117    step_3   step_2  0 days 00:01:09
# 4       781255054_21935453173_531117    step_2   step_3  0 days 00:00:09
# ...                              ...       ...      ...              ...
# 172701  586047816_14599436811_389185    step_1   step_2  0 days 00:00:55
# 172702  586047816_14599436811_389185    step_2   step_1  0 days 00:00:02
# 172703  586047816_14599436811_389185    step_1   step_2  0 days 00:00:39
# 172704  586047816_14599436811_389185    step_2   step_3  0 days 00:00:30
# 172705  586047816_14599436811_389185    step_3  confirm  0 days 00:00:34
#
#         is_error
# 0          False
# 1          False
# 2          False
# 3           True
# 4          False
# ...          ...
# 172701     False
# 172702      True
# 172703     False
# 172704     False
# 172705     False
#
# [172706 rows x 8 columns]

# %%
df.to_csv('../data/clean/time_spent_variation.csv', index = False)

# %% [markdown]
# # Merge all results into one dataframe

# %% [markdown]
# 1. Completion rate per step
#     - step 1
#     - step 2
#     - step 3
#     - confirm
#
#
# 2. Time spent on each step
#     - step 1
#     - step 2
#     - step 3
#     - confirm
#
#
# 3. Error rate
#
#
# 4. Time spent on errors

# %% [markdown]
# ## Read 1

# %%
completion_rate_step_test = pd.read_csv('../data/intermediate_steps/completion_rate_step_test.csv')
completion_rate_step_test.drop('Unnamed: 0', axis = 1, inplace = True)
completion_rate_step_test
# Out:
#       Step  Percentage
# 0    start  100.000000
# 1   step_1   83.515699
# 2   step_2   70.934121
# 3   step_3   63.846229
# 4  confirm   53.875126

# %%
completion_rate_step_control = pd.read_csv('../data/intermediate_steps/completion_rate_step_control.csv')
completion_rate_step_control.drop('Unnamed: 0', axis = 1, inplace = True)
completion_rate_step_control
# Out:
#       Step  Percentage
# 0    start  100.000000
# 1   step_1   73.509307
# 2   step_2   61.380447
# 3   step_3   54.797210
# 4  confirm   46.187822

# %% [markdown]
# ## Read 2

# %%
average_time_spent_test = pd.read_csv('../data/intermediate_steps/average_time_spent_test.csv')
average_time_spent_test.drop('from_step', axis = 1, inplace = True)
average_time_spent_test.drop('Unnamed: 0', axis = 1, inplace = True)
average_time_spent_test
# Out:
#    to_step             avg_time_spent
# 0   step_1  0 days 00:00:56.984656210
# 1   step_2  0 days 00:00:41.813417548
# 2   step_3  0 days 00:01:30.230584275
# 3  confirm  0 days 00:01:50.698065449

# %%
average_time_spent_control = pd.read_csv('../data/intermediate_steps/average_time_spent_control.csv')
average_time_spent_control.drop('from_step', axis = 1, inplace = True)
average_time_spent_control.drop('Unnamed: 0', axis = 1, inplace = True)
average_time_spent_control
# Out:
#    to_step             avg_time_spent
# 0   step_1  0 days 00:01:04.276945972
# 1   step_2  0 days 00:00:37.193225006
# 2   step_3  0 days 00:01:33.193533460
# 3  confirm  0 days 00:02:14.721029065

# %% [markdown]
# ## Read 3 & 4

# %%
errors_test = pd.read_csv('../data/intermediate_steps/errors_test.csv')
errors_test.drop('Unnamed: 0', axis = 1, inplace = True)
errors_test
# Out:
#   to_step  Percentage             avg_time_spent
# 0   error    7.760498  0 days 00:02:24.306587615

# %%
errors_control = pd.read_csv('../data/intermediate_steps/errors_control.csv')
errors_control.drop('Unnamed: 0', axis = 1, inplace = True)
errors_control
# Out:
#   to_step  Percentage             avg_time_spent
# 0   error    5.414974  0 days 00:01:57.116456945

# %% [markdown]
# # Make a big data frame

# %%
a_test = pd.merge(completion_rate_step_test, average_time_spent_test, on = 'to_step')
b_test = pd.concat([a_test, errors_test])
b_test['Variation'] = 'Test'
b_test.to_csv('../data/clean/results_test.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19872\4276718251.py in ?()
# ----> 1 a_test = pd.merge(completion_rate_step_test, average_time_spent_test, on = 'to_step')
#       2 b_test = pd.concat([a_test, errors_test])
#       3 b_test['Variation'] = 'Test'
#       4 b_test.to_csv('../data/clean/results_test.csv')
#
# D:\Downloads DISCO GIGANTE\data analytics\ironhack\labs\vanguard-ab-test\.venv\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# D:\Downloads DISCO GIGANTE\data analytics\ironhack\labs\vanguard-ab-test\.venv\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# D:\Downloads DISCO GIGANTE\data analytics\ironhack\labs\vanguard-ab-test\.venv\Lib\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1306                     if lk is not None:
#    1307                         # Then we're either Hashable or a wrong-length arraylike,
#    1308                         #  the latter of which will raise
#    1309                         lk = cast(Hashable, lk)
# -> 1310                         left_keys.append(left._get_label_or_level_values(lk))
#    1311                         join_names.append(lk)
#    1312                     else:
#    1313                         # work-around for merge_asof(left_index=True)
#
# D:\Downloads DISCO GIGANTE\data analytics\ironhack\labs\vanguard-ab-test\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'to_step'

# %%
a_control = pd.merge(completion_rate_step_control, average_time_spent_control, on = 'to_step')
b_control = pd.concat([a_control, errors_control])
b_control['Variation'] = 'Control'
b_control.to_csv('../data/clean/results_control.csv')

# %%
df = pd.concat([b_test, b_control], axis = 0)
df.to_csv('../data/clean/results.csv')
